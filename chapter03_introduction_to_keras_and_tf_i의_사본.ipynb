# %% [markdown]
# <a href="https://colab.research.google.com/github/cherest555/CLASS_AI4DL/blob/main/chapter03_introduction_to_keras_and_tf_i%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Introduction to Keras and TensorFlow

# %% [markdown]
# ## What's TensorFlow?

# %% [markdown]
# ## What's Keras?

# %% [markdown]
# ## Keras and TensorFlow: A brief history

# %% [markdown]
# ## Setting up a deep-learning workspace

# %% [markdown]
# ### Jupyter notebooks: The preferred way to run deep-learning experiments

# %% [markdown]
# ### Using Colaboratory

# %% [markdown]
# #### First steps with Colaboratory

# %% [markdown]
# #### Installing packages with pip

# %% [markdown]
# #### Using the GPU runtime

# %% [markdown]
# ## First steps with TensorFlow

# %% [markdown]
# #### Constant tensors and variables

# %% [markdown]
# **All-ones or all-zeros tensors**

# %%
import tensorflow as tf
x = tf.ones(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[1.]
#  [1.]], shape=(2, 1), dtype=float32)

# %%
x = tf.zeros(shape=(2, 1))
print(x)
# Out:
# tf.Tensor(
# [[0.]
#  [0.]], shape=(2, 1), dtype=float32)

# %% [markdown]
# **Random tensors**

# %%
x = tf.random.normal(shape=(3, 1), mean=0., stddev=1.)
print(x)
# Out:
# tf.Tensor(
# [[-0.0934263 ]
#  [-0.5050919 ]
#  [ 0.28402638]], shape=(3, 1), dtype=float32)

# %%
x = tf.random.uniform(shape=(3, 1), minval=0., maxval=1.)
print(x)
# Out:
# tf.Tensor(
# [[0.21161139]
#  [0.48722994]
#  [0.15468287]], shape=(3, 1), dtype=float32)

# %% [markdown]
# **NumPy arrays are assignable**

# %%
import numpy as np
x = np.ones(shape=(2, 2))
x[0, 0] = 0.

# %% [markdown]
# **Creating a TensorFlow variable**

# %%
v = tf.Variable(initial_value=tf.random.normal(shape=(3, 1)))
print(v)
# Out:
# <tf.Variable 'Variable:0' shape=(3, 1) dtype=float32, numpy=
# array([[0.19313344],
#        [1.0316784 ],
#        [0.33816576]], dtype=float32)>

# %% [markdown]
# **Assigning a value to a TensorFlow variable**

# %%
v.assign(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **Assigning a value to a subset of a TensorFlow variable**

# %%
v[0, 0].assign(3.)
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[3.],
#        [1.],
#        [1.]], dtype=float32)>

# %% [markdown]
# **Using `assign_add`**

# %%
v.assign_add(tf.ones((3, 1)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(3, 1) dtype=float32, numpy=
# array([[4.],
#        [2.],
#        [2.]], dtype=float32)>

# %% [markdown]
# #### Tensor operations: Doing math in TensorFlow

# %% [markdown]
# **A few basic math operations**

# %%
a = tf.ones((2, 2))
b = tf.square(a)
c = tf.sqrt(a)
d = b + c
e = tf.matmul(a, b)
e *= d

# %% [markdown]
# #### A second look at the GradientTape API

# %% [markdown]
# **Using the `GradientTape`**

# %%
input_var = tf.Variable(initial_value=3.)
with tf.GradientTape() as tape:
   result = tf.square(input_var)
gradient = tape.gradient(result, input_var)

# %% [markdown]
# **Using `GradientTape` with constant tensor inputs**

# %%
input_const = tf.constant(3.)
with tf.GradientTape() as tape:
   tape.watch(input_const)
   result = tf.square(input_const)
gradient = tape.gradient(result, input_const)

# %% [markdown]
# **Using nested gradient tapes to compute second-order gradients**

# %%
time = tf.Variable(0.)
with tf.GradientTape() as outer_tape:
    with tf.GradientTape() as inner_tape:
        position =  4.9 * time ** 2
    speed = inner_tape.gradient(position, time)
acceleration = outer_tape.gradient(speed, time)

# %% [markdown]
# #### An end-to-end example: A linear classifier in pure TensorFlow

# %% [markdown]
# **Generating two classes of random points in a 2D plane**

# %%
num_samples_per_class = 1000
negative_samples = np.random.multivariate_normal(
    mean=[0, 3],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)
positive_samples = np.random.multivariate_normal(
    mean=[3, 0],
    cov=[[1, 0.5],[0.5, 1]],
    size=num_samples_per_class)

num_samples_per_class=500

negative_samples=np.random.multivariate_normal( mean=[2,3],cov=[[1,0.2],[0.5,1]], size=num_samples_per_class)
positive_samples=np.random.multivariate_normal( mean=[3,1],cov=[[1,0.5],[0.5,1]], size=num_samples_per_class)

import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets[:, 0])
plt.show()
# Out:
# <ipython-input-64-c3715113b639>:13: RuntimeWarning: covariance is not positive-semidefinite.
#   negative_samples=np.random.multivariate_normal( mean=[2,3],cov=[[1,0.2],[0.5,1]], size=num_samples_per_class)

# %% [markdown]
# **Stacking the two classes into an array with shape (2000, 2)**

# %%
inputs = np.vstack((negative_samples, positive_samples)).astype(np.float32)

# %% [markdown]
# **Generating the corresponding targets (0 and 1)**

# %%
targets = np.vstack((np.zeros((num_samples_per_class, 1), dtype="float32"),
                     np.ones((num_samples_per_class, 1), dtype="float32")))

# %% [markdown]
# **Plotting the two point classes**

# %%
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets[:, 0])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets[:, 0])
plt.show()

# %% [markdown]
# **Creating the linear classifier variables**

# %%
input_dim = 2
output_dim = 1
W = tf.Variable(initial_value=tf.random.uniform(shape=(input_dim, output_dim)))
b = tf.Variable(initial_value=tf.zeros(shape=(output_dim,)))

# %% [markdown]
# **The forward pass function**

# %%
def model(inputs):
    return tf.matmul(inputs, W) + b

# %% [markdown]
# **The mean squared error loss function**

# %%
def square_loss(targets, predictions):
    per_sample_losses = tf.square(targets - predictions)
    return tf.reduce_mean(per_sample_losses)

# %% [markdown]
# **The training step function**

# %%
learning_rate = 0.1

def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(targets, predictions)
    grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    W.assign_sub(grad_loss_wrt_W * learning_rate)
    b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

learning_rate = 0.05

def training_step(inputs, targets):
    with tf.GradientTape() as tape:
        predictions = model(inputs)
        loss = square_loss(targets, predictions)
    grad_loss_wrt_W, grad_loss_wrt_b = tape.gradient(loss, [W, b])
    W.assign_sub(grad_loss_wrt_W * learning_rate)
    b.assign_sub(grad_loss_wrt_b * learning_rate)
    return loss

# %% [markdown]
# **The batch training loop**

# %%
for step in range(100):
    loss = training_step(inputs, targets)
    print(f"Loss at step {step}: {loss:.4f}")
# Out:
# Loss at step 0: 0.9928
# Loss at step 1: 0.3392
# Loss at step 2: 0.2370
# Loss at step 3: 0.1976
# Loss at step 4: 0.1732
# Loss at step 5: 0.1566
# Loss at step 6: 0.1452
# Loss at step 7: 0.1371
# Loss at step 8: 0.1314
# Loss at step 9: 0.1272
# Loss at step 10: 0.1241
# Loss at step 11: 0.1218
# Loss at step 12: 0.1199
# Loss at step 13: 0.1185
# Loss at step 14: 0.1172
# Loss at step 15: 0.1161
# Loss at step 16: 0.1152
# Loss at step 17: 0.1143
# Loss at step 18: 0.1135
# Loss at step 19: 0.1127
# Loss at step 20: 0.1120
# Loss at step 21: 0.1113
# Loss at step 22: 0.1106
# Loss at step 23: 0.1100
# Loss at step 24: 0.1093
# Loss at step 25: 0.1087
# Loss at step 26: 0.1081
# Loss at step 27: 0.1076
# Loss at step 28: 0.1070
# Loss at step 29: 0.1064
# Loss at step 30: 0.1059
# Loss at step 31: 0.1054
# Loss at step 32: 0.1049
# Loss at step 33: 0.1044
# Loss at step 34: 0.1039
# Loss at step 35: 0.1034
# Loss at step 36: 0.1030
# Loss at step 37: 0.1025
# Loss at step 38: 0.1021
# Loss at step 39: 0.1017
# Loss at step 40: 0.1012
# Loss at step 41: 0.1008
# Loss at step 42: 0.1004
# Loss at step 43: 0.1000
# Loss at step 44: 0.0997
# Loss at step 45: 0.0993
# Loss at step 46: 0.0989
# Loss at step 47: 0.0986
# Loss at step 48: 0.0982
# Loss at step 49: 0.0979
# Loss at step 50: 0.0976
# Loss at step 51: 0.0973
# Loss at step 52: 0.0970
# Loss at step 53: 0.0967
# Loss at step 54: 0.0964
# Loss at step 55: 0.0961
# Loss at step 56: 0.0958
# Loss at step 57: 0.0955
# Loss at step 58: 0.0952
# Loss at step 59: 0.0950
# Loss at step 60: 0.0947
# Loss at step 61: 0.0945
# Loss at step 62: 0.0942
# Loss at step 63: 0.0940
# Loss at step 64: 0.0938
# Loss at step 65: 0.0935
# Loss at step 66: 0.0933
# Loss at step 67: 0.0931
# Loss at step 68: 0.0929
# Loss at step 69: 0.0927
# Loss at step 70: 0.0925
# Loss at step 71: 0.0923
# Loss at step 72: 0.0921
# Loss at step 73: 0.0919
# Loss at step 74: 0.0917
# Loss at step 75: 0.0916
# Loss at step 76: 0.0914
# Loss at step 77: 0.0912
# Loss at step 78: 0.0911
# Loss at step 79: 0.0909
# Loss at step 80: 0.0908
# Loss at step 81: 0.0906
# Loss at step 82: 0.0904
# Loss at step 83: 0.0903
# Loss at step 84: 0.0902
# Loss at step 85: 0.0900
# Loss at step 86: 0.0899
# Loss at step 87: 0.0898
# Loss at step 88: 0.0896
# Loss at step 89: 0.0895
# Loss at step 90: 0.0894
# Loss at step 91: 0.0893
# Loss at step 92: 0.0891
# Loss at step 93: 0.0890
# Loss at step 94: 0.0889
# Loss at step 95: 0.0888
# Loss at step 96: 0.0887
# Loss at step 97: 0.0886
# Loss at step 98: 0.0885
# Loss at step 99: 0.0884

# %%
predictions = model(inputs)
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)
plt.show()

# %%
x = np.linspace(-1, 4, 100)
y = - W[0] /  W[1] * x + (0.5 - b) / W[1]
plt.plot(x, y, "-r")
plt.scatter(inputs[:, 0], inputs[:, 1], c=predictions[:, 0] > 0.5)

# %% [markdown]
# ## Anatomy of a neural network: Understanding core Keras APIs

# %% [markdown]
# ### Layers: The building blocks of deep learning

# %% [markdown]
# #### The base Layer class in Keras

# %% [markdown]
# **A `Dense` layer implemented as a `Layer` subclass**

# %%
from tensorflow import keras

class SimpleDense(keras.layers.Layer):

    def __init__(self, units, activation=None):
        super().__init__()
        self.units = units
        self.activation = activation

    def build(self, input_shape):
        input_dim = input_shape[-1]
        self.W = self.add_weight(shape=(input_dim, self.units),
                                 initializer="random_normal")
        self.b = self.add_weight(shape=(self.units,),
                                 initializer="zeros")

    def call(self, inputs):
        y = tf.matmul(inputs, self.W) + self.b
        if self.activation is not None:
            y = self.activation(y)
        return y

# %%
my_dense = SimpleDense(units=32, activation=tf.nn.relu)
input_tensor = tf.ones(shape=(2, 784))
output_tensor = my_dense(input_tensor)
print(output_tensor.shape)
# Out:
# (2, 32)

# %% [markdown]
# #### Automatic shape inference: Building layers on the fly

# %%
from tensorflow.keras import layers
layer = layers.Dense(32, activation="relu")

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential([
    layers.Dense(32, activation="relu"),
    layers.Dense(32)
])

# %%
model = keras.Sequential([
    SimpleDense(32, activation="relu"),
    SimpleDense(64, activation="relu"),
    SimpleDense(32, activation="relu"),
    SimpleDense(10, activation="softmax")
])

# %% [markdown]
# ### From layers to models

# %% [markdown]
# ### The "compile" step: Configuring the learning process

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer="rmsprop",
              loss="mean_squared_error",
              metrics=["accuracy"])

# %%
model.compile(optimizer=keras.optimizers.RMSprop(),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

# %% [markdown]
# ### Picking a loss function

# %% [markdown]
# ### Understanding the fit() method

# %% [markdown]
# **Calling `fit()` with NumPy data**

# %%
history = model.fit(
    inputs,
    targets,
    epochs=5,
    batch_size=128
)
# Out:
# Epoch 1/5
# 16/16 [==============================] - 3s 9ms/step - loss: 6.7651 - binary_accuracy: 0.0110
# Epoch 2/5
# 16/16 [==============================] - 0s 9ms/step - loss: 6.4500 - binary_accuracy: 0.0110
# Epoch 3/5
# 16/16 [==============================] - 0s 7ms/step - loss: 6.1831 - binary_accuracy: 0.0110
# Epoch 4/5
# 16/16 [==============================] - 0s 4ms/step - loss: 5.9271 - binary_accuracy: 0.0110
# Epoch 5/5
# 16/16 [==============================] - 0s 4ms/step - loss: 5.6776 - binary_accuracy: 0.0110

# %%
history.history
# Out:
# {'loss': [6.765109539031982,
#   6.4499945640563965,
#   6.183131694793701,
#   5.927122592926025,
#   5.677600860595703],
#  'binary_accuracy': [0.010999999940395355,
#   0.010999999940395355,
#   0.010999999940395355,
#   0.010999999940395355,
#   0.010999999940395355]}

# %% [markdown]
# ### Monitoring loss and metrics on validation data

# %% [markdown]
# **Using the `validation_data` argument**

# %%
model = keras.Sequential([keras.layers.Dense(1)])
model.compile(optimizer=keras.optimizers.RMSprop(learning_rate=0.1),
              loss=keras.losses.MeanSquaredError(),
              metrics=[keras.metrics.BinaryAccuracy()])

indices_permutation = np.random.permutation(len(inputs))
shuffled_inputs = inputs[indices_permutation]
shuffled_targets = targets[indices_permutation]

num_validation_samples = int(0.3 * len(inputs))
val_inputs = shuffled_inputs[:num_validation_samples]
val_targets = shuffled_targets[:num_validation_samples]
training_inputs = shuffled_inputs[num_validation_samples:]
training_targets = shuffled_targets[num_validation_samples:]
model.fit(
    training_inputs,
    training_targets,
    epochs=5,
    batch_size=16,
    validation_data=(val_inputs, val_targets)
)
# Out:
# Epoch 1/5
# 88/88 [==============================] - 2s 9ms/step - loss: 0.1615 - binary_accuracy: 0.9186 - val_loss: 0.1017 - val_binary_accuracy: 0.8800
# Epoch 2/5
# 88/88 [==============================] - 1s 7ms/step - loss: 0.0708 - binary_accuracy: 0.9614 - val_loss: 0.0326 - val_binary_accuracy: 0.9983
# Epoch 3/5
# 88/88 [==============================] - 1s 11ms/step - loss: 0.0684 - binary_accuracy: 0.9607 - val_loss: 0.0547 - val_binary_accuracy: 0.9917
# Epoch 4/5
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0682 - binary_accuracy: 0.9586 - val_loss: 0.0752 - val_binary_accuracy: 0.9433
# Epoch 5/5
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0768 - binary_accuracy: 0.9450 - val_loss: 0.0299 - val_binary_accuracy: 0.9983

# %% [markdown]
# ### Inference: Using a model after training

# %%
predictions = model.predict(val_inputs, batch_size=128)
print(predictions[:10])
# Out:
# 5/5 [==============================] - 0s 2ms/step
# [[ 1.033848  ]
#  [ 1.2079701 ]
#  [-0.12432945]
#  [ 0.8121253 ]
#  [-0.06097662]
#  [ 0.7594122 ]
#  [-0.0498932 ]
#  [ 0.24818191]
#  [-0.03473586]
#  [ 0.9480907 ]]

# %% [markdown]
# ## Summary
